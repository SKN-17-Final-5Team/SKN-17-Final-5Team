# %% [markdown]
# # 공유 Qdrant에 어떤 collections들 있는지 확인용

# %% [markdown]
# ## 리스트
# (밑에 셀에 다 삭제하는 코드 있음)

# %%
import os
from dotenv import load_dotenv
from qdrant_client import QdrantClient

# Load Qdrant credentials from the project .env file
load_dotenv()

client = QdrantClient(
    url=os.environ["QDRANT_URL"],
    api_key=os.environ["QDRANT_API_KEY"],
)

collections_resp = client.get_collections()

total_cnt = 0
for coll in collections_resp.collections:
    total_cnt += 1
    info = client.get_collection(coll.name)  # CollectionInfo
    vectors = info.vectors_count or {}
    total_vectors = sum(v.count for v in vectors.values()) if vectors else "n/a"

    print(
        f"- {coll.name} | points: {info.points_count} | vectors: {total_vectors}"
    )

print(f"Total # of collections: {total_cnt}")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api_client.py:134, in ApiClient.send_inner(self, request)
#     133 try:
# --> 134     response = self._client.send(request)
#     135 except Exception as e:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[4], line 13
#       6 load_dotenv()
#       8 client = QdrantClient(
#       9     url=os.environ["QDRANT_URL"],
#      10     api_key=os.environ["QDRANT_API_KEY"],
#      11 )
# ---> 13 collections_resp = client.get_collections()
#      15 total_cnt = 0
#      16 for coll in collections_resp.collections:
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:2210, in QdrantClient.get_collections(self, **kwargs)
#    2203 """Get list name of all existing collections
#    2204
#    2205 Returns:
#    2206     List of the collections
#    2207 """
#    2208 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2210 return self._client.get_collections(**kwargs)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2571, in QdrantRemote.get_collections(self, **kwargs)
#    2560     response = self.grpc_collections.List(
#    2561         grpc.ListCollectionsRequest(), timeout=self._timeout
#    2562     ).collections
#    2563     return types.CollectionsResponse(
#    2564         collections=[
#    2565             GrpcToRest.convert_collection_description(description)
#    2566             for description in response
#    2567         ]
#    2568     )
#    2570 result: Optional[types.CollectionsResponse] = (
# -> 2571     self.http.collections_api.get_collections().result
#    2572 )
#    2573 assert result is not None, "Get collections returned None"
#    2574 return result
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:330, in SyncCollectionsApi.get_collections(self)
#     324 def get_collections(
#     325     self,
#     326 ) -> m.InlineResponse2004:
#     327     """
#     328     Get list name of all existing collections
#     329     """
# --> 330     return self._build_for_get_collections()
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:159, in _CollectionsApi._build_for_get_collections(self)
#     155 """
#     156 Get list name of all existing collections
#     157 """
#     158 headers = {}
# --> 159 return self.api_client.request(
#     160     type_=m.InlineResponse2004,
#     161     method="GET",
#     162     url="/collections",
#     163     headers=headers if headers else None,
#     164 )
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api_client.py:112, in ApiClient.send(self, request, type_)
#     111 def send(self, request: Request, type_: Type[T]) -> T:
# --> 112     response = self.middleware(request, self.send_inner)
#     114     if response.status_code == 429:
#     115         retry_after_s = response.headers.get("Retry-After", None)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api_client.py:250, in BaseMiddleware.__call__(self, request, call_next)
#     249 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 250     return call_next(request)
#
# File /opt/anaconda3/envs/agents_env/lib/python3.12/site-packages/qdrant_client/http/api_client.py:136, in ApiClient.send_inner(self, request)
#     134     response = self._client.send(request)
#     135 except Exception as e:
# --> 136     raise ResponseHandlingException(e)
#     137 return response
#
# ResponseHandlingException: [Errno 8] nodename nor servname provided, or not known

# %% [markdown]
# ## 삭제용

# %%
def delete_all_collections():
    """Delete all collections in Qdrant."""
    collections_resp = client.get_collections()
    
    deleted_count = 0
    for coll in collections_resp.collections:
        try:
            client.delete_collection(coll.name)
            print(f"✓ Deleted collection: {coll.name}")
            deleted_count += 1
        except Exception as e:
            print(f"✗ Failed to delete {coll.name}: {e}")
    
    print(f"\nTotal collections deleted: {deleted_count}")


def delete_target_collection(collection_name: str):
    """
    Delete a specific collection in Qdrant.
    
    Args:
        collection_name: Name of the collection to delete
    """
    try:
        client.delete_collection(collection_name)
        print(f"✓ Successfully deleted collection: {collection_name}")
    except Exception as e:
        print(f"✗ Failed to delete collection '{collection_name}': {e}")

# %% [markdown]
# ### 원하는 거 하나만 지우기

# %%
delete_target_collection("cisg_document_collection")
# Out:
# ✓ Successfully deleted collection: cisg_document_collection

# %% [markdown]
# ### 전부 지우기

# %%
delete_all_collections()  # ⚠️ WARNING: This will delete ALL collections!
# Out:
# ✓ Deleted collection: trade_collection
#
# Total collections deleted: 1

# %% [markdown]
# fraud 데이터 이상한 point/chunk 삭제

# %%
# 방법 2: data_source 필드가 없거나 'fraud'인 포인트 모두 삭제

from qdrant_client import QdrantClient
import os
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "trade_collection"

qdrant = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY"),
    timeout=300
)

print("fraud 관련 포인트 검색 중...")

# 전략: 
# 1. 모든 포인트를 스캔 (scroll API 사용)
# 2. data_source가 없거나 'fraud'인 포인트 ID 수집
# 3. 해당 ID들 삭제

all_points_to_delete = []
offset = None

while True:
    result = qdrant.scroll(
        collection_name=COLLECTION_NAME,
        limit=100,
        offset=offset,
        with_payload=True
    )
    
    points, offset = result
    
    for point in points:
        payload = point.payload or {}
        data_source = payload.get("data_source")
        
        # data_source가 없거나 'fraud'인 경우
        if data_source is None or data_source == 'fraud':
            all_points_to_delete.append(point.id)
    
    if offset is None:
        break

print(f"삭제할 포인트 수: {len(all_points_to_delete)}")

if all_points_to_delete:
    # 배치로 삭제
    batch_size = 100
    for i in range(0, len(all_points_to_delete), batch_size):
        batch = all_points_to_delete[i:i+batch_size]
        qdrant.delete(
            collection_name=COLLECTION_NAME,
            points_selector=batch
        )
        print(f"삭제 진행: {i+len(batch)}/{len(all_points_to_delete)}")
    
    print(f"✓ {len(all_points_to_delete)}개 포인트 삭제 완료")
else:
    print("삭제할 포인트가 없습니다.")

# 삭제 후 확인
collection_info = qdrant.get_collection(COLLECTION_NAME)
print(f"\n현재 총 포인트 수: {collection_info.points_count}")
# Out:
# fraud 관련 포인트 검색 중...
# 삭제할 포인트 수: 154
# 삭제 진행: 100/154
# 삭제 진행: 154/154
# ✓ 154개 포인트 삭제 완료
#
# 현재 총 포인트 수: 1375
