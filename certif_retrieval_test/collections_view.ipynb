# %% [markdown]
# # 공유 Qdrant에 어떤 collections들 있는지 확인용

# %% [markdown]
# ## 리스트
# (밑에 셀에 다 삭제하는 코드 있음)

# %%
import os
from dotenv import load_dotenv
from qdrant_client import QdrantClient

# Load Qdrant credentials from the project .env file
load_dotenv("../.env")

client = QdrantClient(
    url=os.environ["QDRANT_URL"],
    api_key=os.environ["QDRANT_API_KEY"],
)

collections_resp = client.get_collections()

total_cnt = 0
for coll in collections_resp.collections:
    total_cnt += 1
    info = client.get_collection(coll.name)  # CollectionInfo
    vectors = info.vectors_count or {}
    total_vectors = sum(v.count for v in vectors.values()) if vectors else "n/a"

    print(
        f"- {coll.name} | points: {info.points_count} | vectors: {total_vectors}"
    )

print(f"Total # of collections: {total_cnt}")
# Out:
# - csv_collection | points: 0 | vectors: n/a
# - qna_txt_collection | points: 0 | vectors: n/a
# - qna_csv_row_index | points: 47 | vectors: n/a
# - eval_aa04b40a | points: 0 | vectors: n/a
# - qna_csv_field_clause_index | points: 18 | vectors: n/a
# - qna_txt_index | points: 270 | vectors: n/a
# - eval_818d549f | points: 221 | vectors: n/a
# - doc_pre_chunked_legal_parsing_v1 | points: 221 | vectors: n/a
# - eval_a1d481ad | points: 221 | vectors: n/a
# - qna_csv_field_사례내용_index | points: 47 | vectors: n/a
# - eval_a1d0cd0d | points: 0 | vectors: n/a
# - qna_csv_field_case_index | points: 15 | vectors: n/a
# - csv_field_answer_index | points: 17 | vectors: n/a
# - qna_csv_field_근거조항_index | points: 45 | vectors: n/a
# - certifications_no_chunk_openai | points: 454 | vectors: n/a
# - csv_field_clause_index | points: 18 | vectors: n/a
# - certifications_chunk_1000_hf | points: 454 | vectors: n/a
# - doc_pre_chunked_legal_openai_ada002 | points: 221 | vectors: n/a
# - qna_csv_field_question_index | points: 19 | vectors: n/a
# - certifications_chunk_1000_openai_fulltext | points: 532 | vectors: n/a
# - txt_index | points: 127 | vectors: n/a
# - doc_pre_chunked_legal_bge_m3 | points: 221 | vectors: n/a
# - certifications_chunk_1000_openai | points: 100 | vectors: n/a
# - eval_bcc107a1 | points: 0 | vectors: n/a
# - eval_5328ec25 | points: 0 | vectors: n/a
# - eval_dde0f238 | points: 0 | vectors: n/a
# - qna_csv_cell_index | points: 139 | vectors: n/a
# - certifications_chunk_1000_hf_v2 | points: 454 | vectors: n/a
# - certifications | points: 454 | vectors: n/a
# - csv_field_question_index | points: 19 | vectors: n/a
# - eval_ba9b4a35 | points: 0 | vectors: n/a
# - certifications_no_chunk_hf | points: 454 | vectors: n/a
# - csv_field_case_index | points: 15 | vectors: n/a
# - qna_csv_field_answer_index | points: 17 | vectors: n/a
# - certifications_chunk_2000_openai | points: 454 | vectors: n/a
# - csv_row_index | points: 19 | vectors: n/a
# - qna_csv_field_답변_index | points: 47 | vectors: n/a
# - eval_ff71bb38 | points: 0 | vectors: n/a
# - eval_807bf619 | points: 0 | vectors: n/a
# - certifications_chunk_500_openai | points: 454 | vectors: n/a
# - certifications_no_chunk_openai_fulltext | points: 454 | vectors: n/a
# - treaty_articles | points: 214 | vectors: n/a
# - eval_35ea414b | points: 0 | vectors: n/a
# - eval_bdee063c | points: 221 | vectors: n/a
# - txt_collection | points: 127 | vectors: n/a
# - qna_csv_collection | points: 0 | vectors: n/a
# - trade_fraud | points: 151 | vectors: n/a
# Total # of collections: 47

# %% [markdown]
# ## 전체 삭제

# %%
def delete_all_collections():
    """Delete all collections in Qdrant."""
    collections_resp = client.get_collections()
    
    deleted_count = 0
    for coll in collections_resp.collections:
        try:
            client.delete_collection(coll.name)
            print(f"✓ Deleted collection: {coll.name}")
            deleted_count += 1
        except Exception as e:
            print(f"✗ Failed to delete {coll.name}: {e}")
    
    print(f"\nTotal collections deleted: {deleted_count}")


def delete_target_collection(collection_name: str):
    """
    Delete a specific collection in Qdrant.
    
    Args:
        collection_name: Name of the collection to delete
    """
    try:
        client.delete_collection(collection_name)
        print(f"✓ Successfully deleted collection: {collection_name}")
    except Exception as e:
        print(f"✗ Failed to delete collection '{collection_name}': {e}")

# %% [markdown]
# ### 원하는 거 하나만 지우기

# %%
delete_target_collection("certifications_chunk_500_openai")

# %% [markdown]
# ### 전부 지우기

# %%
delete_all_collections()  # ⚠️ WARNING: This will delete ALL collections!
# Out:
# ✓ Deleted collection: csv_collection
# ✓ Deleted collection: qna_txt_collection
# ✓ Deleted collection: qna_csv_row_index
# ✓ Deleted collection: eval_aa04b40a
# ✓ Deleted collection: qna_csv_field_clause_index
# ✓ Deleted collection: qna_txt_index
# ✓ Deleted collection: eval_818d549f
# ✓ Deleted collection: doc_pre_chunked_legal_parsing_v1
# ✓ Deleted collection: qna_csv_field_사례내용_index
# ✓ Deleted collection: eval_a1d0cd0d
# ✓ Deleted collection: qna_csv_field_case_index
# ✓ Deleted collection: csv_field_answer_index
# ✓ Deleted collection: eval_1734dafe
# ✓ Deleted collection: qna_csv_field_근거조항_index
# ✓ Deleted collection: certifications_no_chunk_openai
# ✓ Deleted collection: csv_field_clause_index
# ✓ Deleted collection: certifications_chunk_1000_hf
# ✓ Deleted collection: doc_pre_chunked_legal_openai_ada002
# ✓ Deleted collection: qna_csv_field_question_index
# ✓ Deleted collection: certifications_chunk_1000_openai_fulltext
# ✓ Deleted collection: txt_index
# ✓ Deleted collection: doc_pre_chunked_legal_bge_m3
# ✓ Deleted collection: certifications_chunk_1000_openai
# ✓ Deleted collection: eval_bcc107a1
# ✓ Deleted collection: eval_5328ec25
# ✓ Deleted collection: eval_dde0f238
# ✓ Deleted collection: qna_csv_cell_index
# ✓ Deleted collection: certifications_chunk_1000_hf_v2
# ✓ Deleted collection: certifications
# ✓ Deleted collection: csv_field_question_index
# ✓ Deleted collection: eval_ba9b4a35
# ✓ Deleted collection: certifications_no_chunk_hf
# ✓ Deleted collection: csv_field_case_index
# ✓ Deleted collection: qna_csv_field_answer_index
# ✓ Deleted collection: certifications_chunk_2000_openai
# ✓ Deleted collection: csv_row_index
# ✓ Deleted collection: qna_csv_field_답변_index
# ✓ Deleted collection: eval_ff71bb38
# ✓ Deleted collection: eval_807bf619
# ✓ Deleted collection: certifications_chunk_500_openai
# ✓ Deleted collection: certifications_no_chunk_openai_fulltext
# ✓ Deleted collection: treaty_articles
# ✓ Deleted collection: eval_35ea414b
# ✓ Deleted collection: eval_bdee063c
# ✓ Deleted collection: txt_collection
# ✓ Deleted collection: qna_csv_collection
# ✓ Deleted collection: trade_fraud
#
# Total collections deleted: 47
